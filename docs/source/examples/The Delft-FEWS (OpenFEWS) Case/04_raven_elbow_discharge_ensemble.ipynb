# %% [markdown]
# # 04 - Raven Discharge Ensemble Forecasts

# %% [markdown]
# ## Learning goals of this module
# - Learn how to do a basic analysis, comparing observed discharge with forecast discharge, produced by Raven and forced by GEPS, GEFS and IFS.
# - Learn about ensemble forecast verification.
# - Learn how to calculate and visualize simple error metrics, such as the __rank_histogram__ and the __continuous_ranked_probability_score__.
#
# ## Assumptions
# - We assume you are familiar with the concept of a __probabilistic__ forecast.
# - We assume you are familiar with the concept of a __hydrological__ model.
#
# ### Reference to ensemble forecast products
#
# - [Global Ensemble Prediction System (GEPS)](https://open.canada.ca/data/en/dataset/6d9dd2f8-202e-58cb-a110-e2168832aacb)
#
# - [Global Ensemble Forecast System (GEFS)](https://www.ncei.noaa.gov/products/weather-climate-models/global-ensemble-forecast)
#
# - [Integrated Forecasting System (IFS)](https://www.ecmwf.int/en/forecasts/documentation-and-support/changes-ecmwf-model)
#
# ### Reference to Raven
# [Raven Hydrological Model](https://raven.uwaterloo.ca/)

# %% [markdown]
# ## Run imports and set-up logging

# %%
import logging
import sys
import warnings
from pathlib import Path

from dotenv import load_dotenv

from veriflow import run_pipeline
from veriflow.constants import VERSION

# add project root (parent of notebook folder) to path
sys.path.append(str(Path("..").resolve()))


from tree_plots import (
    crps_plot,
    forecast_timeseries_plot,
    get_pair_dataset,
    rank_histogram_3d_plot,
    rank_histogram_plot,
    scatter_plot,
)

# Reload automatically
# %load_ext autoreload
# %autoreload 2


warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

load_dotenv(dotenv_path="tutorial.env", override=True)

base_config = Path("config")
base_config.exists()

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)
logging.info(f"Running Veriflow version {VERSION}")
# Out:
# 2026-06-18 22:49:17,077 - INFO - Running Veriflow version 0.1.0

# %% [markdown]
# ## Inspecting the _veriflow_ pipeline configuration
# 1. Open the config file in the "config" directory. The name of the file is identical to the name of the notebook.
# 2. Inspect each of the sections to gain an understanding of what this configuration is about.

# %% [markdown]
# ## Running the _veriflow_ pipeline

# %%
ods = run_pipeline((base_config / "04_raven_elbow_discharge_ensemble.yaml", "yaml"))
# Out:
# 2026-06-18 22:49:17,331 - INFO - Successfully initialized the configuration.
# 	 verification_period_start = 2025-05-20 00:00:00
# 	 verification_period_end = 2026-06-01 00:00:00
# 2026-06-18 22:49:17,340 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:49:18,007 - INFO - Successfully got observed data from FewsWebservice.
# 2026-06-18 22:49:18,008 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:49:18,693 - INFO - Successfully got simulated_GEPS data from FewsWebservice.
# 2026-06-18 22:49:18,694 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:49:19,598 - INFO - Successfully got simulated_GEFS data from FewsWebservice.
# 2026-06-18 22:49:19,600 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:49:20,632 - INFO - Successfully got simulated_IFS data from FewsWebservice.
# 2026-06-18 22:49:20,637 - INFO - Successfully loaded all data from sources.
# 2026-06-18 22:49:20,703 - INFO - Successfully computed CrpsForEnsemble for verification pair QR_GEPS.
# 2026-06-18 22:49:20,774 - INFO - Successfully computed CrpsForEnsemble for verification pair QR_GEFS.
# 2026-06-18 22:49:20,852 - INFO - Successfully computed CrpsForEnsemble for verification pair QR_IFS.
# 2026-06-18 22:49:20,949 - INFO - Successfully computed RankHistogram for verification pair QR_GEPS.
# 2026-06-18 22:49:20,991 - INFO - Successfully computed RankHistogram for verification pair QR_GEFS.
# 2026-06-18 22:49:21,038 - INFO - Successfully computed RankHistogram for verification pair QR_IFS.
# 2026-06-18 22:49:21,040 - INFO - Verification pipeline completed successfully.

# %%
ods
# Out:
# OutputDataset with 3 verification pairs: [VerificationPair(id='QR_GEPS', obs='observed', sim='simulated_GEPS', variable='discharge'), VerificationPair(id='QR_GEFS', obs='observed', sim='simulated_GEFS', variable='discharge'), VerificationPair(id='QR_IFS', obs='observed', sim='simulated_IFS', variable='discharge')]

# %% [markdown]
# ## Evaluating the results in the _veriflow_ output `DataTree`

# %% [markdown]
# Verification metrics and results can contain a level of abstraction. Although these abstractions can reveal important information about forecast quality, a basic "eyeball verification" is often the best and intuitive way to start your verification exercise. You'll likely find strengths and weaknesses in your forecasts early on, without directly diving into levels of abstraction. In addition, a solid visual inspection may help you later on in understanding or explaining the more abstract results.

# %% [markdown]
# ### 1 - Visual inspection of observed and forecast data
# A good starting point for "eyeball" verification is simple: just looking at your observations and forecasts in a visual way. Use the interactive elements in the plots below to zoom, pan and compare the results of our 3 NWP products.

# %%
stations = get_pair_dataset(ods, ods.veriflow.verification_pairs[0]).coords["station"].values
lead_times = get_pair_dataset(ods, ods.veriflow.verification_pairs[0]).coords["lead_time"].values

# %%
forecast_timeseries_plot(ods)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>
# <div style="height:1020px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="d8528112-150b-43a8-9db6-c7883790268e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d8528112-150b-43a8-9db6-c7883790268e")) {                    Plotly.newPlot(                        "d8528112-150b-43a8-9db6-c7883790268e",                        [{"legendgroup":"observed","line":{"color":"#022B6D","width":2},"mode":"lines","name":"observed","showlegend":true,"x":["2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAoJmZJ0AAAABgZmYmQAAAAAAAACVAAAAAQDMzJEAAAAAghesjQAAAAGBmZiRAAAAAoHA9I0AAAACAPQojQAAAAMDMTCNAAAAAwMzMJEAAAAAAAAAoQAAAAAAAAC9AAAAAwMzMOEAAAACgmRk6QAAAAAAAgDtAAAAAAAAAP0AAAAAAAABHQAAAAEAz01VAAAAAwMysVEAAAACgmZlQQAAAAGBm5k1AAAAAoJlZSEAAAABgZuZDQA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(122, 73, 28, 0.15)","hoverinfo":"skip","legendgroup":"spread","line":{"color":"rgba(0, 0, 0, 0)"},"name":"ensemble spread (10-90%)","showlegend":true,"x":["2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-16T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAYBIDFUAAAACgm0QiQAAAAMBySEpAAAAAIFokP0AAAACgxEA9QAAAAOCn5jpAAAAAoBovJUAAAAAgWmQoQAAAAEDfDypAAAAAQLbzJkAAAACAwEoVQAAAAADTTRRA"},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"mean","line":{"color":"#7A491C","width":1.5},"mode":"lines","name":"ensemble mean forecast","showlegend":true,"x":["2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"JUmS5CenFECGYRjG9LIdQJIkSfqW9DlAMQzDAJUoN0AMwzBsvNQ0QMMwDCMO7zJA"},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(122, 73, 28, 0.15)","hoverinfo":"skip","legendgroup":"spread","line":{"color":"rgba(0, 0, 0, 0)"},"name":"ensemble spread (10-90%)","showlegend":false,"x":["2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-17T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAA4E\u002fNLUAAAACAP51ZQAAAAOB6xEFAAAAA4CIbP0AAAAAgg6A\u002fQAAAACCy\u002fUFAAAAAgOvRMEAAAABA328yQAAAACBc7zNAAAAAANMtNkAAAABgkS0xQAAAAGAOLRxA"},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"mean","line":{"color":"#7A491C","width":1.5},"mode":"lines","name":"ensemble mean forecast","showlegend":false,"x":["2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000" ...

# %% [markdown]
# ### 2 - Visual inspection with a scatter plot per lead time
# Another great tool for "eyeball" verification is the scatter plot. The scatter plot is relatively easy to understand, but is slightly more abstract than the visualization above.
#
# For all forecasts in our output `DataTree`, we collect all realizations of the ensemble at a specific lead time. You can use the  `lead_times` variable  (a list of `np.timedelta64` instances) to slice the data at a specific lead time. For that given slice, we can make the scatter plot.

# %%
scatter_plot(ods, lead_time=lead_times[1])
# Out:
# <div style="height:840px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="de77d549-33a9-4377-bfad-ad2400b2f1f5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("de77d549-33a9-4377-bfad-ad2400b2f1f5")) {                    Plotly.newPlot(                        "de77d549-33a9-4377-bfad-ad2400b2f1f5",                        [{"legendgroup":"members","marker":{"color":"#61BD4D","size":5,"symbol":"circle"},"mode":"markers","name":"ensemble members","showlegend":true,"x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"j8ILQQRWqkBqvMxA\u002fKkvQcl2\u002fkBmZu5AiUGkQPLS7UBqvApBNV4IQZHtrECBlRdB9P3oQN0kEkFvEqdAbef\u002fQAAADkGDwLpArBwEQUJgyUD8qbFAnMTNQVg5+0G+n5pBarwwQotsiUGBVRxD\u002fOnMQqRwAUNC4FZC+n6MQWZmi0LBytJB4XrzQSUGtEGe76dBCteGQVTjKUJ\u002faptBi2x7QbByo0ESgxNCDAKGQRKDjUF9P4dB2\u002fmqQaJFokHLoblBlkOnQQiskkHRIpVBSgyoQZqZgEGoxoxBLbKUQU5itEF56ZZBrBytQYcWkEFcj9hB\\u002fQZqZtkHTTcBBc2i9QbKdtkE5tLlBf2q2QSGws0Ej27tBHVq2QY\u002fCsUHNzMRB46WyQYPAvEGynbJBkxjBQfp+tEHNzLFB30+1QUSLvUHByrdBPQqdQd9PmkHLoZpBCteoQd9PmkFokZpBYhCbQTEIm0FKDKdBObSaQZHtmkEQWJpBtvOjQRKDnUEIrKNBQmCaQQRWoEEdWppBXI+aQYtsmkFkO5tBXrqGQUa2hkEtsoZBUriGQZHtiEGPwoZB8tKNQW3niUErh4hBUI2HQYPAhkFSuIZBVOOGQY\u002fChkEX2YZBd76GQRfZjUEtsoZBnu+HQS2yhkH4U4dBz\\u002fKk3QRsvL0Feuj1Bd75PQQwCQ0EOLXJBokVAQX0\u002fM0GNl4FBJzFmQc3MXEHpJl1B7FFoQXNoY0FkO4FBokVkQcHKYUGsHGJBuB5dQQIrq0FCYIFBXrpxQVg5aEH0\u002fWBBg8B2QaRwb0Fg5Y5BpptcQdEihkEGgYdBDAKEQfCnhUGWQ4RBYhCEQZqZ00GcxMJBhet\u002fQSuHfEFokYBBarzWQTvfk0G6SeBBy6GEQWq80EHwp4RBMQiDQajGo0HFIKJBpHB\..."},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"mean","marker":{"color":"#7A491C","size":7,"symbol":"circle"},"mode":"markers","name":"ensemble mean","showlegend":true,"x":{"dtype":"f4","bdata":"MzMzQQAAKEGamSFBKVwfQTMzI0GF6xlB7FEYQWZmGkFmZiZBAABAQQAAeEFmZsZBzczQQQAA3EEAAPhBAAA4QpqZrkJmZqVC"},"y":{"dtype":"f4","bdata":"ppftQDAQL0JsqJxBcruWQQJqikH86J9BU+u4QRJMnUFa4odBCO9rQR7UT0EYzUNBVfpzQcVbmUGFOoZBaJWrQb6cJ0OOjjtD"},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"reference","line":{"color":"#818181","dash":"dash","width":1},"mode":"lines","name":"1:1 line","showlegend":true,"x":[-14.049400401115417,407.9634061574936],"y":[-14.049400401115417,407.9634061574936],"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"members","marker":{"color":"#61BD4D","size":5,"symbol":"circle"},"mode":"markers","name":"ensemble members","showlegend":false,"x":{"dtype":"f4","bdata":"..."},"y":{"dtype":"f4","bdata":"UI1RQb6fMkHZzmdBuB5PQX0\u002fN0EK17tAvp9MQXWTHkEtsmVB2c43QS2yAUHP9xtByXa1QUoMOEGWQwFBxSDkQSPbVUHb+TBBF9kcQd9Pb0FKDHRBpptwQT0KhEFeunVBN4mxQcUgTkFYOTZB8tIKQqjGaUHjpYJBnMTYQEw3YUKBlXtCx4vNQhdZikLheq9BXA8IQiXGh0Lb+cZBdZPQQQ4tekGYrqVCaJH9QZjulULjJYRCWDkAQkjh5kGY7glCKbw3Qy\u002fdyEGsnEdCEFi+QQBAxULppnVCTmIcQmIQhkFS+JFCRItzQr6f30G6SWpC\u002fCk9QilcUUI5tKNBHVqOQWiRm0ESg5RBBFaHQVpkt0FokbhBSgzCQQaBwEF\u002fartBPzWTQZzEnUHNzKdB+n6KQbbz90HP95tBZLsXQsdLpkEhsK1BsHK7QfLSiEGF66lB5\u002fu5QQIrhkFkO6dBd76dQeXQtkGsHLlBFK7FQWiRl0GgGsBB5\u002fuxQbgeqEHRIqFBmpm+QQRWpEFMN5tBYOXcQZzEqkGsHLlB16OjQTvfqkGwcqJB2\u002fmmQRkEmEH6fqJBGy+QQRBYrUFcj ...

# %% [markdown]
# ### 3 - Looking into the Continuous Ranked Probability Score
#
# Next, we'll look into the results of the continuous ranked probability score. Before you continue to the next section, we'll look into the documentation and do a tutorial on the CRPS for ensemble forecasts. The _veriflow_ package relies on _scores_ (developed by the Bureau of Meteorology, Australia) for computation of various scores.
#
# 1. Read the [API documentation](https://scores.readthedocs.io/en/stable/api.html#scores.probability.crps_for_ensemble) the __crps_for_ensemble__ function, which is used under the hood in _veriflow_.
# 2. Run through the [scores tutorial](https://scores.readthedocs.io/en/stable/tutorials/CRPS_for_Ensembles.html) on the __crps_for_ensemble__ function. You can run it in Binder (link on top of the page), or view the static view.
#
#
# - Q1: what attribute(s) of forecast quality can be measured by the CRPS?
#
# <details>
# <summary>Show suggested answers for Q1</summary>
# The CRPS captures multiple attributes: accuracy, reliability and sharpness. Can you reason why?
#
# </details>
#
# - Q2: what is the best possible CRPS score?
#
# <details>
# <summary>Show suggested answers for Q2</summary>
# The best possible outcome of CRPS is 0. In this case the forecast has maximum sharpness: all ensemble members exactly predict the observed outcome.
# </details>
#
#
# - Q3: computing the CRPS over just one realization (i.e. a deterministic forecast) yields the exact same result as computing the ... for a deterministic score?
#
# <details>
# <summary>Show suggested answers for Q3</summary>
# The absolute error. The CRPS is a probabilistic generalization of the absolute error. When taking the mean of the CRPS over all forecasts, it is equal to the mean absolute error when the number of realizations is 1.
# </details>

# %%
crps_plot(ods)
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="513ee4d1-c776-4967-8057-d46eb27bca88" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("513ee4d1-c776-4967-8057-d46eb27bca88")) {                    Plotly.newPlot(                        "513ee4d1-c776-4967-8057-d46eb27bca88",                        [{"legendgroup":"crps_for_ensemble","mode":"lines+markers","name":"QR_GEPS - 05BJ010","x":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"y":{"dtype":"f8","bdata":"RlEUnQj6I0A4EXVludwrQAW0mdty4zJAi5SBSy3GJ0D2iSXark8kQGEia2FaMyJA"},"type":"scatter"},{"legendgroup":"crps_for_ensemble","mode":"lines+markers","name":"QR_GEFS - 05BJ010","x":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"y":{"dtype":"f8","bdata":"dSfz9dmWJUBd3BMpNWwmQIvFfmWt1CVAdnI9sAp5I0D+9cHLDoAiQO9JTnsbsiNA"},"type":"scatter"},{"legendgroup":"crps_for_ensemble","mode":"lines+markers","name":"QR_IFS - 05BJ010","x":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"y":{"dtype":"f8","bdata":"RYgD\u002ffX7JUAxY7Lw4kolQKn\u002fjpzENyRArOgkOR23H0CiNONorSEeQCHGayda9iBA"},"type":"scatter"}],                        {"template":{"layout":{"font":{"color":"#022B6D","family":"Segoe UI, Arial, sans-serif"},"paper_bgcolor":"#FFFFFF","plot_bgcolor":"#FFFFFF"}},"xaxis":{"title":{"text":"Lead Time (h)"},"tickmode":"array","tickvals":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"ticktext":["24 h","48 h","72 h","96 h","120 h","144 h"]},"yaxis":{"title":{"text":"CRPS_FOR_ENSEMBLE"}},"hovermode":"x unified","title":{"text":"CRPS vs Lead Time for 3 Verification Pair(s)"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('513ee4d1-c776-4967-8057-d46eb27bca88');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ### 4 - Looking into the Rank Histogram
#
# Next, we'll look into the results of the rank histogram. Before you continue to the next section, we'll look into the documentation and do a tutorial on the rank histogram for ensemble forecasts. The _veriflow_ package relies on _scores_ (developed by the Bureau of Meteorology, Australia) for computation of various scores.
#
# 1. Read the [API documentation](https://scores.readthedocs.io/en/stable/api.html#scores.probability.rank_histogram) the __rank_histogram__ function, which is used under the hood in _veriflow_.
# 2. Run through the [scores tutorial](https://scores.readthedocs.io/en/stable/tutorials/Rank_Histogram.html) on the __rank_histogram__ function. You can run it in Binder (link on top of the page), or view the static view.
#
# - Q1: what attribute(s) of forecast quality can be measured by the Rank Histogram?
#
# <details>
# <summary>Show suggested answers for Q1</summary>
# The rank histogram primarily measures reliability, although bias in forecasts will show up in the rank histogram as well.
# </details>
#
# - Q2: what does a perfect Rank Histogram look like?
#
# <details>
# <summary>Show suggested answers for Q2</summary>
# The rank histogram shows a uniform (flat) distribution, indicating forecast and observed frequencies are equal.
# </details>
#
# - Q3: does a perfectly uniform/flat rank histogram always correspond to a good forecast? Can you come up with a hypothetical forecast that has a perfect rank histogram, but is still bad?
#
# <details>
# <summary>Show suggested answers for Q3</summary>
# No, although a perfect rank histogram indicates statistical reliability, the forecast may still have poor resolution (the ability to discriminate between situations that have different observed outcomes).
#
# Imagine an ensemble forecast that ignores current conditions and simply samples from the historical distribution of streamflow for that day of year.
#
# For example, every day in June the ensemble consists of random draws from the last 30 years of June observations.
#
# This forecast can also produce a nearly uniform rank histogram because the observations come from the same climatological distribution. However, it has zero ability to distinguish today's conditions from any other June day.
#
# </details>

# %%
rank_histogram_plot(ods, station=stations[0], lead_time=lead_times[4])
# Out:
# <div style="height:760px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="92c39433-0412-4503-9408-40d10dfcdf71" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("92c39433-0412-4503-9408-40d10dfcdf71")) {                    Plotly.newPlot(                        "92c39433-0412-4503-9408-40d10dfcdf71",                        [{"marker":{"color":"#7A491C"},"showlegend":false,"x":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEAAAAAAAAAgQAAAAAAAACJAAAAAAAAAJEAAAAAAAAAmQAAAAAAAAChAAAAAAAAAKkAAAAAAAAAsQAAAAAAAAC5AAAAAAAAAMEAAAAAAAAAxQAAAAAAAADJAAAAAAAAAM0AAAAAAAAA0QAAAAAAAADVAAAAAAAAANkA="},"y":{"dtype":"i1","bdata":"BwIAAAAAAAACAAAAAQEAAAAAAgEBAQ=="},"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#7A491C"},"showlegend":false,"x":{"dtype":"f8","bdata":""},"y":{"dtype":"i1","bdata":"BwAAAAAAAAAAAAAAAAAAAQAAAgABAgEAAAECAAAAAQA="},"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#7A491C"},"showlegend":false,"x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"i1","bdata":"BAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAAIAAQAAAAAAAQEAAAEAAAABAgAAAA=="},"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"layout":{"font":{"color":"#022B6D","family":"Segoe UI, Arial, sans-serif"},"paper_bgcolor":"#FFFFFF","plot_bgcolor":"#FFFFFF"}},"xaxis":{"anchor":"y","domain":[0.0,0.44],"title":{"text":"Rank"}},"yaxis":{"anchor":"x","domain":[0.6000000000000001,1.0],"title":{"text":"Count"}},"xaxis2":{"anchor":"y2","domain":[0.56,1.0],"title":{"text":"Rank"}},"yaxis2":{"anchor":"x2","domain":[0.6000000000000001,1.0],"title":{"text":"Count"}},"xaxis3":{"anchor":"y3","domain":[0.0,0.44],"title":{"text":"Rank"}},"yaxis3":{"anchor":"x3","domain":[0.0,0.4],"title":{"text":"Count"}},"xaxis4":{"anchor":"y4","domain":[0.56,1.0]},"yaxis4":{"anchor":"x4","domain":[0.0,0.4]},"annotations":[{"font":{"size":16},"showarrow":false,"text":"QR_GEPS, station 05BJ010, lead time 120 h","x":0.22,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"QR_GEFS, station 05BJ010, lead time 120 h","x":0.78,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"QR_IFS, station 05BJ010, lead time 120 h","x":0.22,"xanchor":"center","xref":"paper","y":0.4,"yanchor":"bottom","yref":"paper"}],"height":760,"title":{"text":"Rank Histograms for 3 Verification Pair(s)"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('92c39433-0412-4503-9408-40d10dfcdf71');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ### 5 - Looking into the Rank Histogram in 3D (advanced)
# This might seem relatively abstract or advanced, but the 3D rank histogram shows the rank histogram for all lead times. In the current notebook, the number of samples is too low to make a proper analysis of the results, but with many samples this can be an interesting and useful visualization.

# %%
rank_histogram_3d_plot(ods, station=stations[0])
# Out:
# <div style="height:960px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="e6f7c882-6428-4f8c-a37a-f942a9156d13" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e6f7c882-6428-4f8c-a37a-f942a9156d13")) {                    Plotly.newPlot(                        "e6f7c882-6428-4f8c-a37a-f942a9156d13",                        [{"colorbar":{"title":{"text":"Count"}},"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]],"hovertemplate":"Rank: %{x}\u003cbr\u003eLead time: %{y} h\u003cbr\u003eCount: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","showscale":true,"x":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEAAAAAAAAAgQAAAAAAAACJAAAAAAAAAJEAAAAAAAAAmQAAAAAAAAChAAAAAAAAAKkAAAAAAAAAsQAAAAAAAAC5AAAAAAAAAMEAAAAAAAAAxQAAAAAAAADJAAAAAAAAAM0AAAAAAAAA0QAAAAAAAADVAAAAAAAAANkA="},"y":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"z":{"dtype":"f8","bdata":"AAAAAAAAIkAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA\u002fAAAAAAAAHEAAAAAAAAAiQAAAAAAAAPA\...\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAABRAAAAAAAAAIkAAAAAAAADwPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADwPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADwPwAAAAAAAAAAAAAAAAAAEEAAAAAAAAAcQAAAAAAAAABAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADwPwAAAAAAAPA\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAABhAAAAAAAAAAAAAAAAAAADwPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAAAAAAAAAAAAAABAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAAAA","shape":"6, 22"},"type":"surface","scene":"scene"},{"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]],"hovertemplate":"Rank: %{x}\u003cbr\u003eLead time: %{y} h\u003cbr\u003eCount: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","showscale":false,"x":{"dtype":"f8","bdata":""},"y":{"dtype":"f8","bdata":"AAAAAAAAOEAAAAAAAABIQAAAAAAAAFJAAAAAAAAAWEAAAAAAAABeQAAAAAAAAGJA"},"z":{"dtype":"f8","bdata":"...\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADwPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAPA\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA\\u002fAAAAAAAAAAAAAA ...

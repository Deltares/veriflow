# %% [markdown]
# # 01 - Precipitation Reanalysis

# %% [markdown]
# ## Learning goals of this module
# - Learn how to do a basic analysis, comparing observed precipitation with reanalysis precipitation from RDPA and HRDPA
# - Learn how to run a simple example to access and compare observed and reanalysis precipitation.
# - Learn how to calculate and visualize simple error metrics
#
# ## Assumptions
# - We assume you are familiar with the concept of a __reanalysis__ product.
#
# ### Reference to reanalysis products
#
# - [High Resolution Deterministic Precipitation Analysis (HRDPA)](https://open.canada.ca/data/en/dataset/eff69d42-ce81-4672-867f-cc3baaf4157a)
#
# - [Regional Deterministic Precipitation Analysis (RDPA)](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-regional-precipitation-analysis.html#toc0)

# %% [markdown]
# ## Run imports and set-up logging

# %%
import logging
import sys
import warnings
from pathlib import Path

from dotenv import load_dotenv

from veriflow import run_pipeline
from veriflow.constants import VERSION

# add project root (parent of notebook folder) to path
sys.path.append(str(Path("..").resolve()))


from tree_plots import (
    get_pair_dataset,
    reanalysis_timeseries_plot,
)

# Reload automatically
# %load_ext autoreload
# %autoreload 2


warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

load_dotenv(dotenv_path="tutorial.env", override=True)

base_config = Path("config")
base_config.exists()

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)
logging.info(f"Running Veriflow version {VERSION}")
# Out:
# 2026-06-18 22:29:50,163 - INFO - Running Veriflow version 0.1.0
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Inspecting the _veriflow_ pipeline configuration
# 1. Open the config file in the "config" directory. The name of the file is identical to the name of the notebook.
# 2. Inspect each of the sections to gain an understanding of what this configuration is about.
#
# We are pulling from FEWS webservices (you will see this as downloads from urls)
# - Station Observations
# - RDPA Analysis at Stations
# - HRDPA Analysis at Stations

# %% [markdown]
# ## Running the _veriflow_ pipeline

# %%
config_file = base_config / "01_elbow_precipitation_analysis.yaml"
ods = run_pipeline(config=(config_file, "yaml"))
# Out:
# 2026-06-18 22:29:50,486 - INFO - Successfully initialized the configuration.
# 	 verification_period_start = 2026-05-15 00:00:00
# 	 verification_period_end = 2026-06-08 00:00:00
# 2026-06-18 22:29:50,532 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:29:51,712 - INFO - Successfully got data from FewsWebservice.
# 2026-06-18 22:29:51,714 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:29:52,399 - INFO - Successfully got data from FewsWebservice.
# 2026-06-18 22:29:52,400 - INFO - Start getting data from FewsWebservice.
# 2026-06-18 22:29:52,946 - INFO - Successfully got data from FewsWebservice.
# 2026-06-18 22:29:52,950 - INFO - Successfully loaded all data from sources.
# 2026-06-18 22:29:52,983 - INFO - Successfully computed ContinuousScores for verification pair PC_RDPA.
# 2026-06-18 22:29:53,021 - INFO - Successfully computed ContinuousScores for verification pair PC_HRDPA.
# 2026-06-18 22:29:53,023 - INFO - Verification pipeline completed successfully.

# %% [markdown]
# ## Evaluating the results in the _veriflow_ output `DataTree`

# %% [markdown]
# A good starting point for "eyeball" verification is simple: just looking at your observations and re-analysis in a visual way. Use the interactive elements in the plots below to zoom, pan and compare the results of our 2 re-analysis products.

# %% [markdown]
# ### 1 - Check out the stations in the `DataTree`

# %%
stations = get_pair_dataset(ods, ods.veriflow.verification_pairs[0]).coords["station"].values
print(f"Stations: {stations}")
# Out:
# Stations: ['3031092' '3050778' 'MSC-005' '05BL813' '05BJ804' '05BL809' 'FIRES-B4'
#  '05BJ805' '05BL812' 'FIRES-B5' '05BJ806' '05BH803' '05BF825' '05BH802'
#  '05BL810' '05BF827']

# %% [markdown]
# ### 2 - Visualize the precipitation (per station)

# %%
reanalysis_timeseries_plot(ods, station=stations[5])
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>
# <div style="height:680px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="22c1089a-719d-4fc3-aa59-d6bcca5dcb95" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("22c1089a-719d-4fc3-aa59-d6bcca5dcb95")) {                    Plotly.newPlot(                        "22c1089a-719d-4fc3-aa59-d6bcca5dcb95",                        [{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003eobserved: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"1-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADgPwAAAMDMzCNAAAAAwMzMBEAAAAAAAAAAAAAAAEAzM+M\u002fAAAAwMzMHEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAwMzMBEAAAADAzMzsPwAAAKCZmck\u002fAAAAAAAAAAAAAADAzMwAQAAAAKCZGTVAAAAAoJmZQEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003esimulated_RDPA: %{y}\u003cextra\u003esimulated_RDPA\u003c\u002fextra\u003e","legendgroup":"1-simulated_RDPA","line":{"color":"#7A491C","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"simulated_RDPA","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAIPRspj8AAAAAvAVSPwAAAGBESSVAAAAAYDAq6z8AAADALm7pPwAAAEAD+AlAAAAAYAfOiT8AAADAlpDPPwAAAAArh3Y\u002fAAAAQCqpMz8AAADgTWJAPwAAAOB46cY\u002fAAAAYLE\u002fBkAAAABg3nEAQAAAAIDk8n8\u002fAAAAYJhMhT8AAADAyhE7QAAAAOBW9ENAAAAA4PDkP0AAAAAAzhn0PwAAAIBjXbw\u002fAAAAAAAAAAAAAACAl25yPwAAAACxUMM\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003eobserved: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"2-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":false,"x":["2026-05-15T00:00 ...

# %% [markdown]
# ### 3 - Visualize the precipitation (per station) and add the absolute error to the plot as well

# %%
reanalysis_timeseries_plot(ods, station=stations[4], error_var="mae")
# Out:
# <div style="height:680px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="19c8a442-a9c7-4227-85ea-c5a7c4abcd60" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("19c8a442-a9c7-4227-85ea-c5a7c4abcd60")) {                    Plotly.newPlot(                        "19c8a442-a9c7-4227-85ea-c5a7c4abcd60",                        [{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003eobserved: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"1-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAC5AAAAAoJmZ2T8AAAAAAAAAAAAAAKCZmek\u002fAAAAQDMzE0AAAAAAAAAAAAAAAEAzM+M\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAoJmZ2T8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAD4PwAAAAAAADlAAAAAQDPzREAAAABAMzMkQAAAAAAAAAAAAAAAAAAAAAAAAACgmZnJPwAAAAAAAAAAAAAAAAAAAAA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003esimulated_RDPA: %{y}\u003cextra\u003esimulated_RDPA\u003c\u002fextra\u003e","legendgroup":"1-simulated_RDPA","line":{"color":"#7A491C","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"simulated_RDPA","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAKrxkj8AAAAAvAVSPwAAAIC+rzNAAAAA4K4l1D8AAAAARiXFPwAAAEDNO\u002f4\u002fAAAAQF66uT8AAABAETbMPwAAAGBmZrY\u002fAAAAAAAAAAAAAABAKqkzPwAAAIBs57s\u002fAAAAICh+8j8AAADgtYTMPwAAAAAAAAAAAAAA4OI2ej8AAADgk2c5QAAAAIA4bkNAAAAAgOuxP0AAAABg07zzPwAAAECtab4\u002fAAAAAAAAAAAAAAAACYqfPwAAAIBIv+U\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003emae: %{y}\u003cextra\u003emae\u003c\u002fextra\u003e","legendgroup":"1-mae","line":{"color":"#818181","dash":"dot","width":1.5},"marker":{"size":5,"symbol":"diamond"},"mode":"lines+markers","name":"mae","opacity":1.0,"showlegend":true,"x":["2026-05- ...

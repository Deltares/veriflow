# %% [markdown]
# # Tutorial Overview

# %% [markdown]
# | Title | Contents | Link |
# |------|----------|------|
# | 1a - Basics | An example case-study comparing multiple models by running one integrated verification pipeline and visualizing results with reusable plotting functions. | [Open Notebook](1a_basics.ipynb) |
# | 1b - Interpretation | Continuation focusing on interpretation of results and custom Python plotting using the output `DataTree`. | [Open Notebook](1b_interpretation.ipynb) |

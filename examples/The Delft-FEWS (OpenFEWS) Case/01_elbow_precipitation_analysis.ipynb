# %% [markdown]
# # 01 - Precipitation Reanalysis

# %% [markdown]
# ## Learning goals of this module
# - Learn how to do a basic analysis, comparing observed precipitation with reanalysis precipitation from RDPA and HRDPA
# - Learn how to run a simple example to access and compare observed and reanalysis precipitation.
# - Learn how to calculate and visualize simple error metrics
#
# ## Assumptions
# - We assume you are familiar with the concept of a __reanalysis__ product.
#
# ### Reference to reanalysis products
#
# - [High Resolution Deterministic Precipitation Analysis (HRDPA)](https://open.canada.ca/data/en/dataset/eff69d42-ce81-4672-867f-cc3baaf4157a)
#
# - [Regional Deterministic Precipitation Analysis (RDPA)](https://www.canada.ca/en/environment-climate-change/services/climate-change/canadian-centre-climate-services/display-download/technical-documentation-regional-precipitation-analysis.html#toc0)

# %% [markdown]
# ## Run imports and set-up logging

# %%
import logging
import sys
import warnings
from pathlib import Path

from dotenv import load_dotenv

from veriflow import run_pipeline
from veriflow.constants import VERSION

# add project root (parent of notebook folder) to path
sys.path.append(str(Path("..").resolve()))


from tree_plots import (
    get_pair_dataset,
    reanalysis_timeseries_plot,
)

# Reload automatically
# %load_ext autoreload
# %autoreload 2


warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

load_dotenv(dotenv_path="tutorial.env", override=True)

base_config = Path("config")
base_config.exists()

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)
logging.info(f"Running Veriflow version {VERSION}")
# Out:
# 2026-09-17 13:26:13,868 - INFO - Running Veriflow version 0.4.1

# %% [markdown]
# ## Inspecting the _veriflow_ pipeline configuration
# 1. Open the config file in the "config" directory. The name of the file is identical to the name of the notebook.
# 2. Inspect each of the sections to gain an understanding of what this configuration is about.
#
# We are pulling from FEWS webservices (you will see this as downloads from urls)
# - Station Observations
# - RDPA Analysis at Stations
# - HRDPA Analysis at Stations

# %% [markdown]
# ## Running the _veriflow_ pipeline

# %%
config_file = base_config / "01_elbow_precipitation_analysis.yaml"
dt = run_pipeline(config=(config_file, "yaml"))
# Out:
# 2026-09-17 13:39:57,596 - INFO - Successfully initialized the configuration.
# 	 verification_period_start = 2026-05-15 00:00:00
# 	 verification_period_end = 2026-06-08 00:00:00
# 2026-09-17 13:39:58,254 - INFO - Starting data fetch for observed from FewsWebservice.
# 2026-09-17 13:39:59,480 - INFO - Download successful from URL: https://veriflow-open.fews.deltares.nl/FewsWebServices/rest/fewspiservice/v1/timeseries?locationIds=3031092&locationIds=3050778&locationIds=MSC-005&locationIds=05BL813&locationIds=05BJ804&locationIds=05BL809&locationIds=FIRES-B4&locationIds=05BJ805&locationIds=05BL812&locationIds=FIRES-B5&locationIds=05BJ806&locationIds=05BH803&locationIds=05BF825&locationIds=05BH802&locationIds=05BL810&locationIds=05BF827&parameterIds=PC.obs&moduleInstanceIds=ImportMeteoStations&startTime=2026-05-15T00%3A00%3A00Z&endTime=2026-06-08T00%3A00%3A00Z&timeSeriesType=EXTERNAL_HISTORICAL&documentFormat=PI_NETCDF
# 2026-09-17 13:39:59,494 - INFO - Starting data fetch for observed from FewsNetCDF.
# 2026-09-17 13:40:07,993 - INFO - Starting data fetch for simulated_RDPA from FewsWebservice.
# 2026-09-17 13:40:08,895 - INFO - Download successful from URL: https://veriflow-open.fews.deltares.nl/FewsWebServices/rest/fewspiservice/v1/timeseries?locationIds=3031092&locationIds=3050778&locationIds=MSC-005&locationIds=05BL813&locationIds=05BJ804&locationIds=05BL809&locationIds=FIRES-B4&locationIds=05BJ805&locationIds=05BL812&locationIds=FIRES-B5&locationIds=05BJ806&locationIds=05BH803&locationIds=05BF825&locationIds=05BH802&locationIds=05BL810&locationIds=05BF827&parameterIds=PC.sim&moduleInstanceIds=PreprocessRDPA&startTime=2026-05-15T00%3A00%3A00Z&endTime=2026-06-08T00%3A00%3A00Z&timeSeriesType=EXTERNAL_HISTORICAL&documentFormat=PI_NETCDF
# 2026-09-17 13:40:08,962 - INFO - Starting data fetch for simulated_RDPA from FewsNetCDF.
# 2026-09-17 13:40:12,573 - INFO - Starting data fetch for simulated_HRDPA from FewsWebservice.
# 2026-09-17 13:40:13,095 - INFO - Download successful from URL: https://veriflow-open.fews.deltares.nl/FewsWebServices/rest/fewspiservice/v1/timeseries?locationIds=3031092&locationIds=3050778&locationIds=MSC-005&locationIds=05BL813&locationIds=05BJ804&locationIds=05BL809&locationIds=FIRES-B4&locationIds=05BJ805&locationIds=05BL812&locationIds=FIRES-B5&locationIds=05BJ806&locationIds=05BH803&locationIds=05BF825&locationIds=05BH802&locationIds=05BL810&locationIds=05BF827&parameterIds=PC.sim&moduleInstanceIds=PreprocessHRDPA&startTime=2026-05-15T00%3A00%3A00Z&endTime=2026-06-08T00%3A00%3A00Z&timeSeriesType=EXTERNAL_HISTORICAL&documentFormat=PI_NETCDF
# 2026-09-17 13:40:13,098 - INFO - Starting data fetch for simulated_HRDPA from FewsNetCDF.
# 2026-09-17 13:43:09,818 - INFO - Successfully loaded all data from sources.
# 2026-09-17 13:43:10,968 - INFO - Successfully computed ContinuousScores for verification pair PC_RDPA.
# 2026-09-17 13:43:10,990 - INFO - Successfully computed ContinuousScores for verification pair PC_HRDPA.
# 2026-09-17 13:43:10,990 - INFO - Verification pipeline completed successfully.

# %%
dt
# Out:
# <xarray.DataTree 'veriflow-datatree'>
# Group: /
# ├── Group: /input_data
# │   ├── Group: /input_data/observed
# │   │       Dimensions:       (station: 16, time: 25)
# │   │       Coordinates:
# │   │         * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │   │           station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │   │           lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │           lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │           y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │           x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │           z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │   │         * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │   │       Data variables:
# │   │           PC            (station, time) float32 2kB 0.0 2.3 0.2 0.2 ... 0.0 0.0 4.4
# │   │       Attributes: (12/14)
# │   │           originalParameterId:  PC.obs
# │   │           Conventions:          CF-1.6
# │   │           coordinate_system:    WGS 1984
# │   │           featureType:          timeSeries
# │   │           time_coverage_start:  2026-05-15T00:00:00+0000
# │   │           time_coverage_end:    2026-06-08T00:00:00+0000
# │   │           ...                   ...
# │   │           geospatial_lat_min:   50.4859
# │   │           geospatial_lat_max:   51.1226
# │   │           data_type:            observed_historical
# │   │           source_id:            observed
# │   │           spatial_type:         point
# │   │           crs:                  EPSG:4326
# │   ├── Group: /input_data/simulated_RDPA
# │   │       Dimensions:       (station: 16, time: 25)
# │   │       Coordinates:
# │   │         * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │   │           station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │   │           lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │           lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │           y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │           x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │           z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │   │         * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │   │       Data variables:
# │   │           PC            (station, time) float32 2kB 0.0151 0.0036 ... 0.0849 1.065
# │   │       Attributes: (12/14)
# │   │           originalParameterId:  PC.sim
# │   │           Conventions:          CF-1.6
# │   │           coordinate_system:    WGS 1984
# │   │           featureType:          timeSeries
# │   │           time_coverage_start:  2026-05-15T00:00:00+0000
# │   │           time_coverage_end:    2026-06-08T00:00:00+0000
# │   │           ...                   ...
# │   │           geospatial_lat_min:   50.4859
# │   │           geospatial_lat_max:   51.1226
# │   │           data_type:            observed_historical
# │   │           source_id:            simulated_RDPA
# │   │           spatial_type:         point
# │   │           crs:                  EPSG:4326
# │   └── Group: /input_data/simulated_HRDPA
# │           Dimensions:       (station: 16, time: 25)
# │           Coordinates:
# │             * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │               station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │               lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │               lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │               y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │               x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │               z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │             * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │           Data variables:
# │               PC            (station, time) float32 2kB 0.0115 0.0038 ... 0.042 1.924
# │           Attributes: (12/14)
# │               originalParameterId:  PC.sim
# │               Conventions:          CF-1.6
# │               coordinate_system:    WGS 1984
# │               featureType:          timeSeries
# │               time_coverage_start:  2026-05-15T00:00:00+0000
# │               time_coverage_end:    2026-06-08T00:00:00+0000
# │               ...                   ...
# │               geospatial_lat_min:   50.4859
# │               geospatial_lat_max:   51.1226
# │               data_type:            observed_historical
# │               source_id:            simulated_HRDPA
# │               spatial_type:         point
# │               crs:                  EPSG:4326
# ├── Group: /PC_RDPA
# │   ├── Group: /PC_RDPA/aligned_input
# │   │   ├── Group: /PC_RDPA/aligned_input/observations
# │   │   │       Dimensions:       (station: 16, time: 25)
# │   │   │       Coordinates:
# │   │   │         * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │   │   │           station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │   │   │           lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │   │           lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │   │           y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │   │           x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │   │           z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │   │   │         * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │   │   │       Data variables:
# │   │   │           PC            (station, time) float32 2kB 0.0 2.3 0.2 0.2 ... 0.0 0.0 4.4
# │   │   └── Group: /PC_RDPA/aligned_input/simulations
# │   │           Dimensions:       (station: 16, time: 25)
# │   │           Coordinates:
# │   │             * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │   │               station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │   │               lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │               lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │               y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │   │               x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │   │               z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │   │             * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │   │           Data variables:
# │   │               PC            (station, time) float32 2kB 0.0151 0.0036 ... 0.0849 1.065
# │   └── Group: /PC_RDPA/output
# │       └── Group: /PC_RDPA/output/continuous_scores
# │               Dimensions:       (station: 16, time: 25)
# │               Coordinates:
# │                 * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
# │                   station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
# │                   lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │                   lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │                   y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
# │                   x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
# │                   z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
# │                 * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
# │               Data variables:
# │                   mean_error    (station, time) float32 2kB 0.0151 -2.296 ... 0.0849 -3.335
# │                   mae           (station, time) float32 2kB 0.0151 2.296 ... 0.0849 3.335
# │                   rmse          (station, time) float32 2kB 0.0151 2.296 ... 0.0849 3.335
# │               Attributes:
# │                   units:         mm
# │                   data_type:     observed_historical
# │                   spatial_type:  point
# │                   crs:           EPSG:4326
# └── Group: /PC_HRDPA
#     ├── Group: /PC_HRDPA/aligned_input
#     │   ├── Group: /PC_HRDPA/aligned_input/observations
#     │   │       Dimensions:       (station: 16, time: 25)
#     │   │       Coordinates:
#     │   │         * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
#     │   │           station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
#     │   │           lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#     │   │           lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#     │   │           y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#     │   │           x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#     │   │           z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
#     │   │         * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
#     │   │       Data variables:
#     │   │           PC            (station, time) float32 2kB 0.0 2.3 0.2 0.2 ... 0.0 0.0 4.4
#     │   └── Group: /PC_HRDPA/aligned_input/simulations
#     │           Dimensions:       (station: 16, time: 25)
#     │           Coordinates:
#     │             * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
#     │               station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
#     │               lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#     │               lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#     │               y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#     │               x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#     │               z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
#     │             * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
#     │           Data variables:
#     │               PC            (station, time) float32 2kB 0.0115 0.0038 ... 0.042 1.924
#     └── Group: /PC_HRDPA/output
#         └── Group: /PC_HRDPA/output/continuous_scores
#                 Dimensions:       (station: 16, time: 25)
#                 Coordinates:
#                   * station       (station) <U8 512B '3031092' '3050778' ... '05BL810' '05BF827'
#                     station_name  (station) |S255 4kB b'Calgary International' ... b'Priddis'
#                     lat           (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#                     lon           (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#                     y             (station) float64 128B 51.12 51.08 51.08 ... 51.04 50.65 50.87
#                     x             (station) float64 128B -114.0 -115.1 -115.1 ... -114.6 -114.3
#                     z             (station) float64 128B 1.099e+03 1.321e+03 nan ... nan nan nan
#                   * time          (time) datetime64[ns] 200B 2026-05-15 ... 2026-06-08
#                 Data variables:
#                     mean_error    (station, time) float32 2kB 0.0115 -2.296 ... 0.042 -2.476
#                     mae           (station, time) float32 2kB 0.0115 2.296 8.947 ... 0.042 2.476
#                     rmse          (station, time) float32 2kB 0.0115 2.296 8.947 ... 0.042 2.476
#                 Attributes:
#                     units:         mm
#                     data_type:     observed_historical
#                     spatial_type:  point
#                     crs:           EPSG:4326

# %% [markdown]
# ## Evaluating the results in the _veriflow_ output `DataTree`

# %% [markdown]
# A good starting point for "eyeball" verification is simple: just looking at your observations and re-analysis in a visual way. Use the interactive elements in the plots below to zoom, pan and compare the results of our 2 re-analysis products.

# %% [markdown]
# ### 1 - Check out the stations in the `DataTree`

# %%
stations = get_pair_dataset(dt, dt.veriflow.verification_pairs[0]).coords["station"].values
print(f"Stations: {stations}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 stations = get_pair_dataset(dt, dt.veriflow.verification_pairs[0]).coords["station"].values
#       2 print(f"Stations: {stations}")
#
# NameError: name 'get_pair_dataset' is not defined

# %% [markdown]
# ### 2 - Visualize the precipitation (per station)

# %%
reanalysis_timeseries_plot(dt, station=stations[5])
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.7.0.min"</script>
# <div style="height:680px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="4b0f846f-ad69-4529-a41f-da18dce25988" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4b0f846f-ad69-4529-a41f-da18dce25988")) {                    Plotly.newPlot(                        "4b0f846f-ad69-4529-a41f-da18dce25988",                        [{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003ePC_obs: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"1-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADgPwAAAMDMzCNAAAAAwMzMBEAAAAAAAAAAAAAAAEAzM+M\u002fAAAAwMzMHEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAwMzMBEAAAADAzMzsPwAAAKCZmck\u002fAAAAAAAAAAAAAADAzMwAQAAAAKCZGTVAAAAAoJmZQEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003ePC_sim: %{y}\u003cextra\u003ePC_sim\u003c\u002fextra\u003e","legendgroup":"1-PC_sim","line":{"color":"#7A491C","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"PC_sim","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAIPRspj8AAAAAvAVSPwAAAGBESSVAAAAAYDAq6z8AAADALm7pPwAAAEAD+AlAAAAAYAfOiT8AAADAlpDPPwAAAAArh3Y\u002fAAAAQCqpMz8AAADgTWJAPwAAAOB46cY\u002fAAAAYLE\u002fBkAAAABg3nEAQAAAAIDk8n8\u002fAAAAYJhMhT8AAADAyhE7QAAAAOBW9ENAAAAA4PDkP0AAAAAAzhn0PwAAAIBjXbw\u002fAAAAAAAAAAAAAACAl25yPwAAAACxUMM\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003ePC_obs: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"2-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":false,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00. ...
#
# var gd

# %% [markdown]
# ### 3 - Visualize the precipitation (per station) and add the absolute error to the plot as well

# %%
reanalysis_timeseries_plot(dt, station=stations[4], error_var="mae", error_score_name="continuous_scores")
# Out:
# <div style="height:680px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="bda52cbc-2b1f-4f13-8089-459ac3e59870" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bda52cbc-2b1f-4f13-8089-459ac3e59870")) {                    Plotly.newPlot(                        "bda52cbc-2b1f-4f13-8089-459ac3e59870",                        [{"customdata":["","","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003ePC_obs: %{y}\u003cextra\u003eobserved\u003c\u002fextra\u003e","legendgroup":"1-observed","line":{"color":"#022B6D","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"observed","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-20T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAC5AAAAAoJmZ2T8AAAAAAAAAAAAAAKCZmek\u002fAAAAQDMzE0AAAAAAAAAAAAAAAEAzM+M\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAoJmZ2T8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAD4PwAAAAAAADlAAAAAQDPzREAAAABAMzMkQAAAAAAAAAAAAAAAAAAAAAAAAACgmZnJPwAAAAAAAAAAAAAAAAAAAAA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003ePC_sim: %{y}\u003cextra\u003ePC_sim\u003c\u002fextra\u003e","legendgroup":"1-PC_sim","line":{"color":"#7A491C","width":1.5},"marker":{"size":5},"mode":"lines+markers","name":"PC_sim","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16T00:00:00.000000000","2026-05-17T00:00:00.000000000","2026-05-18T00:00:00.000000000","2026-05-19T00:00:00.000000000","2026-05-21T00:00:00.000000000","2026-05-22T00:00:00.000000000","2026-05-23T00:00:00.000000000","2026-05-24T00:00:00.000000000","2026-05-25T00:00:00.000000000","2026-05-26T00:00:00.000000000","2026-05-27T00:00:00.000000000","2026-05-28T00:00:00.000000000","2026-05-29T00:00:00.000000000","2026-05-30T00:00:00.000000000","2026-05-31T00:00:00.000000000","2026-06-01T00:00:00.000000000","2026-06-02T00:00:00.000000000","2026-06-03T00:00:00.000000000","2026-06-04T00:00:00.000000000","2026-06-05T00:00:00.000000000","2026-06-06T00:00:00.000000000","2026-06-07T00:00:00.000000000","2026-06-08T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAKrxkj8AAAAAvAVSPwAAAIC+rzNAAAAA4K4l1D8AAAAARiXFPwAAAEDNO\u002f4\u002fAAAAQF66uT8AAABAETbMPwAAAGBmZrY\u002fAAAAAAAAAAAAAABAKqkzPwAAAIBs57s\u002fAAAAICh+8j8AAADgtYTMPwAAAAAAAAAAAAAA4OI2ej8AAADgk2c5QAAAAIA4bkNAAAAAgOuxP0AAAABg07zzPwAAAECtab4\u002fAAAAAAAAAAAAAAAACYqfPwAAAIBIv+U\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":["","","","","","","","","","","","","","","","","","","","","","","",""],"hovertemplate":"time: %{x}\u003cbr\u003emae: %{y}\u003cextra\u003emae\u003c\u002fextra\u003e","legendgroup":"1-mae","line":{"color":"#818181","dash":"dot","width":1.5},"marker":{"size":5,"symbol":"diamond"},"mode":"lines+markers","name":"mae","opacity":1.0,"showlegend":true,"x":["2026-05-15T00:00:00.000000000","2026-05-16 ...
